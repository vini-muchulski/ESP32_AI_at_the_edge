# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import numpy as np

INPUT_SHAPE = (96, 96, 3)
NUM_CLASSES = 10
LEARNING_RATE = 0.0001
BATCH_SIZE = 32
INITIAL_EPOCHS = 10
FINE_TUNE_EPOCHS = 10
FINE_TUNE_AT = 100
H5_MODEL_PATH = "cifar10_mobilenetv2_finetuned.h5"
TFLITE_MODEL_PATH = "cifar10_mobilenetv2_finetuned.tflite"
# Out:
# 2025-08-04 23:10:57.893316: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754349058.085601      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754349058.141031      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()

    y_train = to_categorical(y_train, NUM_CLASSES)
    y_test = to_categorical(y_test, NUM_CLASSES)

    def preprocess_image(image, label):
        image = tf.cast(image, tf.float32)
        image = tf.image.resize(image, (INPUT_SHAPE[0], INPUT_SHAPE[1]))
        image = tf.keras.applications.mobilenet_v2.preprocess_input(image)
        return image, label

    train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    train_ds = (
        train_ds.shuffle(buffer_size=1024)
        .map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(BATCH_SIZE)
        .prefetch(tf.data.AUTOTUNE)
    )

    test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
    test_ds = (
        test_ds.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(BATCH_SIZE)
        .prefetch(tf.data.AUTOTUNE)
    )
    return train_ds, test_ds

def build_model():
    base_model = MobileNetV2(input_shape=INPUT_SHAPE,
                             include_top=False,
                             weights='imagenet')
    base_model.trainable = False

    inputs = Input(shape=INPUT_SHAPE)
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.2)(x)
    outputs = Dense(NUM_CLASSES, activation='softmax')(x)
    model = Model(inputs, outputs)
    return model, base_model

def compile_and_train(model, train_ds, test_ds):
    model.compile(optimizer=Adam(learning_rate=LEARNING_RATE),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    history = model.fit(train_ds,
                        epochs=INITIAL_EPOCHS,
                        validation_data=test_ds)
    return history

def fine_tune_model(model, base_model, train_ds, test_ds):
    base_model.trainable = True

    for layer in base_model.layers[:FINE_TUNE_AT]:
        layer.trainable = False

    model.compile(optimizer=Adam(learning_rate=LEARNING_RATE / 10),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    total_epochs = INITIAL_EPOCHS + FINE_TUNE_EPOCHS
    history_fine = model.fit(train_ds,
                             epochs=total_epochs,
                             initial_epoch=INITIAL_EPOCHS,
                             validation_data=test_ds)
    return history_fine

def save_models(model):
    model.save(H5_MODEL_PATH)
    print(f"Model saved to {H5_MODEL_PATH}")

    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite_model = converter.convert()

    with open(TFLITE_MODEL_PATH, 'wb') as f:
        f.write(tflite_model)
    print(f"Model saved to {TFLITE_MODEL_PATH}")

def test_tflite_accuracy(model_path):
    (_, _), (x_test, y_test) = cifar10.load_data()

    interpreter = tf.lite.Interpreter(model_path=model_path)
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()[0]
    output_details = interpreter.get_output_details()[0]

    height = input_details['shape'][1]
    width = input_details['shape'][2]

    correct_predictions = 0
    total_images = len(x_test)

    for i in range(total_images):
        image = x_test[i]
        image_expanded = np.expand_dims(image, axis=0)
        image_resized = tf.image.resize(image_expanded, [height, width])
        image_preprocessed = tf.keras.applications.mobilenet_v2.preprocess_input(image_resized)

        interpreter.set_tensor(input_details['index'], image_preprocessed)
        interpreter.invoke()

        output_data = interpreter.get_tensor(output_details['index'])
        predicted_label = np.argmax(output_data)
        true_label = y_test[i][0]

        if predicted_label == true_label:
            correct_predictions += 1

    accuracy = (correct_predictions / total_images) * 100
    print(f"\nTFLite model accuracy: {accuracy:.2f}% ({correct_predictions}/{total_images})")

# %%
train_ds, test_ds = load_and_preprocess_data()
model, base_model = build_model()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# I0000 00:00:1754349086.139378      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_96_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print("--- Starting Initial Training (Transfer Learning) ---")
compile_and_train(model, train_ds, test_ds)

loss, accuracy = model.evaluate(test_ds)
print(f"\nTest Accuracy (Transfer Learning): {accuracy * 100:.2f}%")
# Out:
# --- Starting Initial Training (Transfer Learning) ---
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754349105.599298      97 service.cc:148] XLA service 0x7e18c0004140 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754349105.599923      97 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1754349106.548376      97 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   18/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.1338 - loss: 3.1476
# I0000 00:00:1754349110.216667      97 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 38s 17ms/step - accuracy: 0.4847 - loss: 1.5991 - val_accuracy: 0.8065 - val_loss: 0.5770
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.7896 - loss: 0.6145 - val_accuracy: 0.8339 - val_loss: 0.4879
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.8207 - loss: 0.5256 - val_accuracy: 0.8445 - val_loss: 0.4542
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.8332 - loss: 0.4813 - val_accuracy: 0.8500 - val_loss: 0.4357
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.8428 - loss: 0.4607 - val_accuracy: 0.8538 - val_loss: 0.4236
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.8493 - loss: 0.4353 - val_accuracy: 0.8571 - val_loss: 0.4143
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.8523 - loss: 0.4239 - val_accuracy: 0.8574 - val_loss: 0.4080
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.8568 - loss: 0.4125 - val_accuracy: 0.8584 - val_loss: 0.4022
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.8606 - loss: 0.4033 - val_accuracy: 0.8591 - val_loss: 0.3995
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.8622 - loss: 0.3984 - val_accuracy: 0.8614 - val_loss: 0.3949
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8641 - loss: 0.3882
#
# Test Accuracy (Transfer Learning): 86.14%

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_96             │ (None, 3, 3, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        12,810 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,296,416 (8.76 MB)
#  Trainable params: 12,810 (50.04 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#  Optimizer params: 25,622 (100.09 KB)

# %%
print("\n--- Starting Fine-Tuning ---")
fine_tune_model(model, base_model, train_ds, test_ds)

loss, accuracy = model.evaluate(test_ds)
print(f"\nFinal Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# --- Starting Fine-Tuning ---
# Epoch 11/20
# E0000 00:00:1754349313.928111      99 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754349314.111639      99 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754349314.375269      99 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754349314.579847      99 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1559/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7789 - loss: 0.6680
# E0000 00:00:1754349346.890508      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754349347.072553      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754349347.323905      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754349347.528221      97 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━
: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618277200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618277584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618277968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618277776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618273360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618279120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618279504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618279888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618279696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618274896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618281040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618281424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618281808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618281616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618276816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618282960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618283344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618283728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618283536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618278736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618284880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618285264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618285648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618285456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618280656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618286800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618287184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618287568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618287376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618282576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618288720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618288336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618287952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618289296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618284496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647618286416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616685456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616684496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616685264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616684304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616686992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616687376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616687760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616687568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616684688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616688912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616689296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616689680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616689488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616685840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616690832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616691216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616691600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616691408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616686608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616692752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616693136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616693520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616693328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616688528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616694672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616695056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616695440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616695248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616690448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616696592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616696976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616697360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616697168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616692368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616698128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647616699856: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1754349615.918035      36 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1754349615.918071      36 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1754349616.072327      36 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# Model saved to cifar10_mobilenetv2_finetuned.tflite
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# TFLite model accuracy: 90.41% (9041/10000)

# %% [markdown]
# # TensorFlow Lite INT8

# %%
import tensorflow as tf
import numpy as np
import os

H5_MODEL_PATH = "cifar10_mobilenetv2_finetuned.h5"
TFLITE_INT8_MODEL_PATH = "cifar10_mobilenetv2_finetuned_int8.tflite"
INPUT_SHAPE = (96, 96, 3)

def representative_dataset_gen():
    (x_train, _), _ = tf.keras.datasets.cifar10.load_data()
    for i in range(100):
        image = x_train[i].astype(np.float32)
        image = tf.image.resize(image, (INPUT_SHAPE[0], INPUT_SHAPE[1]))
        image = tf.keras.applications.mobilenet_v2.preprocess_input(image)
        image = np.expand_dims(image, axis=0)
        yield [image]

converter = tf.lite.TFLiteConverter.from_keras_model(tf.keras.models.load_model(H5_MODEL_PATH))
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_model_quant = converter.convert()

with open(TFLITE_INT8_MODEL_PATH, 'wb') as f:
    f.write(tflite_model_quant)

print(f"INT8 quantized model saved to: {TFLITE_INT8_MODEL_PATH}")
print(f"Original model size: {os.path.getsize(H5_MODEL_PATH) / 1024:.2f} KB")
print(f"INT8 model size: {os.path.getsize(TFLITE_INT8_MODEL_PATH) / 1024:.2f} KB")
# Out:
# Saved artifact at '/tmp/tmpnlmeyfa6'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   138642454074704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454076048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454076432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454076240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454074896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454077584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454077968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454078352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454078160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454075472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454079504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454079888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454080272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454080080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454075664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454081424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454081808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454082192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454082000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454077200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454083344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454083728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454084112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454083920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454079120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647661577616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647663951312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454082576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454075280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454081040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642454082960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453447888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453446928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453447696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453446736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453449424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453449808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453450192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453450000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453447120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453451344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453451728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453452112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453451920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453448272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453453264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453453648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453454032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453453840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453449040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453455184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453455568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453455952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453455760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453450960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453457104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453457488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453457872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453457680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453452880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453459024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453459408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453459792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453459600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453454800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453460944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453461328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453461712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453461520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453456720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453462864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453458640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453496464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453462480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453460560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453497616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453498000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453498384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453498192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453496848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453499536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453499920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453500304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453500112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453496080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453501456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453501840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453502224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453502032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453497232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453503376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453503760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453504144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453503952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453499152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453505296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453505680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453506064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453505872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453501072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453507216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453507600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453507984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453507792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453502992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453509136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453509520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453509904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453509712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453504912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453511056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453510672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453508752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453511632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453506832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453510288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452645072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452644112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452644880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452643920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452646608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452646992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452647376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452647184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452644304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452648528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452648912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452649296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452649104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452645456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452650448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452650832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452651216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452651024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452646224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452652368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452652752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452653136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452652944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452648144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452654288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452654672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452655056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452654864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452650064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452656208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452656976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452656784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452651984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452658512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452658704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452653904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452655824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453643920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452659664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642452657744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453645072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453645456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453645840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453645648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453644304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453646992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453647376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453647760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453647568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453643536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453648912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453649296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453649680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453649488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453644688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453650832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453651216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453651600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453651408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453646608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453652752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453653136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453653520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453653328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453648528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453654672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453655056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453655440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453655248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453650448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453656976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453657360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453652368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453658512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453656208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453659088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453654288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453657744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453742800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453742224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453742992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453742032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453744336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453744720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453745104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453744912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453743184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453746256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453746640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453747024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453746832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453741840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453748176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453748560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453748944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453748752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453743952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453750096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453750480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453750864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453750672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453745872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453752016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453752400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453752784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453752592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453747792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453753936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453754320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453754704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453754512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453749712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453755856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453756240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453756624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453756432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453751632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453757776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453753552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253156496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453757392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138642453755472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253157648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253158032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253158416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253158224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253156880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253159568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253159952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253160336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253160144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253156112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253161488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253161872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253162256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253162064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253157264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253156304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138647253164560: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1754349703.949370      36 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1754349703.949406      36 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# INT8 quantized model saved to: cifar10_mobilenetv2_finetuned_int8.tflite
# Original model size: 23915.88 KB
# INT8 model size: 2657.98 KB
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8

# %%
import tensorflow as tf
import numpy as np

TFLITE_INT8_MODEL_PATH = "cifar10_mobilenetv2_finetuned_int8.tflite"

def test_tflite_int8_accuracy(model_path):
    (_, _), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    interpreter = tf.lite.Interpreter(model_path=model_path)
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()[0]
    output_details = interpreter.get_output_details()[0]

    input_scale, input_zero_point = input_details["quantization"]
    output_scale, output_zero_point = output_details["quantization"]
    
    height = input_details['shape'][1]
    width = input_details['shape'][2]

    correct_predictions = 0
    total_images = len(x_test)

    for i in range(total_images):
        image = x_test[i]
        image_expanded = np.expand_dims(image, axis=0)
        image_resized = tf.image.resize(image_expanded, [height, width])
        image_preprocessed = tf.keras.applications.mobilenet_v2.preprocess_input(image_resized)

        image_quantized = (image_preprocessed / input_scale) + input_zero_point
        image_quantized = tf.cast(image_quantized, dtype=input_details["dtype"])

        interpreter.set_tensor(input_details['index'], image_quantized)
        interpreter.invoke()

        output_data = interpreter.get_tensor(output_details['index'])
        output_data_dequantized = (output_data.astype(np.float32) - output_zero_point) * output_scale
        
        predicted_label = np.argmax(output_data_dequantized)
        true_label = y_test[i][0]

        if predicted_label == true_label:
            correct_predictions += 1
            
    accuracy = (correct_predictions / total_images) * 100
    print(f"\nINT8 TFLite model accuracy: {accuracy:.2f}% ({correct_predictions}/{total_images})")

test_tflite_int8_accuracy(TFLITE_INT8_MODEL_PATH)
# Out:
# INT8 TFLite model accuracy: 74.48% (7448/10000)
