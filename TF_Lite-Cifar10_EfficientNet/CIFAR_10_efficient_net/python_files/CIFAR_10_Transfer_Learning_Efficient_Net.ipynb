# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input, Dropout
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import numpy as np
import os
import matplotlib.pyplot as plt

# --- Configurações ---
INPUT_SHAPE = (224, 224, 3)
NUM_CLASSES = 10
LEARNING_RATE = 1e-3
BATCH_SIZE = 64
INITIAL_EPOCHS = 10
FINE_TUNE_EPOCHS = 10
FINE_TUNE_AT = -20

# --- Callbacks ---
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=1e-6
)

# --- Caminhos dos Arquivos ---
H5_MODEL_PATH = "cifar10_EfficientNetB0_small_finetuned.keras"
TFLITE_MODEL_PATH = "cifar10_EfficientNetB0_small_finetuned.tflite"
TFLITE_INT8_MODEL_PATH = "cifar10_EfficientNetB0_small_finetuned_int8.tflite"

# %%
def load_and_preprocess_data():
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()

    y_train = to_categorical(y_train, NUM_CLASSES)
    y_test = to_categorical(y_test, NUM_CLASSES)

    def format_image(image, label):
        image = tf.cast(image, tf.float32)
        image = tf.image.resize(image, (INPUT_SHAPE[0], INPUT_SHAPE[1]))
        image = preprocess_input(image)
        return image, label

    train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    train_ds = (
        train_ds.shuffle(buffer_size=1024)
        .map(format_image, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(BATCH_SIZE)
        .prefetch(tf.data.AUTOTUNE)
    )

    test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
    test_ds = (
        test_ds.map(format_image, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(BATCH_SIZE)
        .prefetch(tf.data.AUTOTUNE)
    )
    return train_ds, test_ds

def build_model():
    base_model = EfficientNetB0(
        input_shape=INPUT_SHAPE,
        include_top=False,
        weights='imagenet',
        pooling='avg'  # Equivalente ao GlobalAveragePooling2D
    )
    base_model.trainable = False

    inputs = Input(shape=INPUT_SHAPE)
    x = preprocess_input(inputs)  # Pré-processamento específico do EfficientNet
    x = base_model(x, training=False)
    x = Dropout(0.2)(x)  # Mesmo dropout usado no cats/dogs
    outputs = Dense(NUM_CLASSES, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model, base_model


def plot_training_history(history, history_fine):
    """
    Plota as métricas de acurácia e perda do treinamento inicial e do fine-tuning.
    """
    acc = history.history['accuracy'] + history_fine.history['accuracy']
    val_acc = history.history['val_accuracy'] + history_fine.history['val_accuracy']
    loss = history.history['loss'] + history_fine.history['loss']
    val_loss = history.history['val_loss'] + history_fine.history['val_loss']

    initial_epochs = len(history.history['accuracy'])
    total_epochs = len(acc)

    plt.figure(figsize=(14, 6))

    # Gráfico de Acurácia
    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Acurácia de Treino')
    plt.plot(val_acc, label='Acurácia de Validação')
    plt.axvline(initial_epochs - 1, color='gray', linestyle='--', label='Início do Fine-Tuning')
    plt.title('Acurácia do Modelo')
    plt.xlabel('Época')
    plt.ylabel('Acurácia')
    plt.ylim([min(plt.ylim()), 1])
    plt.legend(loc='lower right')

    # Gráfico de Perda
    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Perda de Treino')
    plt.plot(val_loss, label='Perda de Validação')
    plt.axvline(initial_epochs - 1, color='gray', linestyle='--', label='Início do Fine-Tuning')
    plt.title('Perda do Modelo')
    plt.xlabel('Época')
    plt.ylabel('Perda')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()




def save_tflite_model(model, path, is_quantized=False, representative_ds=None):
    """
    Converte um modelo Keras para TFLite, com configuração estrita para
    quantização full-integer.
    """
    converter = tf.lite.TFLiteConverter.from_keras_model(model)

    if is_quantized:
        if representative_ds is None:
            raise ValueError("representative_dataset é necessário para quantização.")

        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        converter.representative_dataset = representative_ds
        converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
        converter.inference_input_type = tf.int8
        converter.inference_output_type = tf.int8
        converter._experimental_new_quantizer = True

    tflite_model = converter.convert()

    with open(path, 'wb') as f:
        f.write(tflite_model)
    print(f"Modelo salvo em {path}")

# %%
# --- 1. Carregar Dados ---
train_ds, test_ds = load_and_preprocess_data()

# --- 2. Construir Modelo ---
model, base_model = build_model()
model.summary()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 10s 0us/step
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 1280)           │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        12,810 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,062,381 (15.50 MB)
#  Trainable params: 12,810 (50.04 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
# --- 3. Treinamento Inicial (Feature Extraction) ---
print("\n--- Iniciando Treinamento Inicial ---")
model.compile(
    optimizer=AdamW(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_ds,
    epochs=INITIAL_EPOCHS,
    validation_data=test_ds,
    callbacks=[early_stopping, reduce_lr]
)

loss, accuracy = model.evaluate(test_ds)
print(f"\nAcurácia (Transfer Learning): {accuracy * 100:.2f}%")
# Out:
# --- Iniciando Treinamento Inicial ---
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 116s 110ms/step - accuracy: 0.7636 - loss: 0.7675 - val_accuracy: 0.8847 - val_loss: 0.3452 - learning_rate: 0.0010
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.8785 - loss: 0.3619 - val_accuracy: 0.8955 - val_loss: 0.3125 - learning_rate: 0.0010
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.8865 - loss: 0.3338 - val_accuracy: 0.9016 - val_loss: 0.2956 - learning_rate: 0.0010
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.8918 - loss: 0.3167 - val_accuracy: 0.9033 - val_loss: 0.2890 - learning_rate: 0.0010
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.8926 - loss: 0.3079 - val_accuracy: 0.9054 - val_loss: 0.2822 - learning_rate: 0.0010
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.8980 - loss: 0.3012 - val_accuracy: 0.9051 - val_loss: 0.2800 - learning_rate: 0.0010
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9001 - loss: 0.2954 - val_accuracy: 0.9060 - val_loss: 0.2771 - learning_rate: 0.0010
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.8978 - loss: 0.2943 - val_accuracy: 0.9083 - val_loss: 0.2734 - learning_rate: 0.0010
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.8981 - loss: 0.2885 - val_accuracy: 0.9065 - val_loss: 0.2780 - learning_rate: 0.0010
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 75ms/step - accuracy: 0.9012 - loss: 0.2847 - val_accuracy: 0.9085 - val_loss: 0.2729 - learning_rate: 0.0010
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.9089 - loss: 0.2759
#
# Acurácia (Transfer Learning): 90.85%

# %%
# --- 4. Fine-Tuning ---
print("\n--- Iniciando Fine-Tuning ---")
base_model.trainable = True
for layer in base_model.layers[:FINE_TUNE_AT]:
    layer.trainable = False

model.compile(
    optimizer=AdamW(learning_rate=LEARNING_RATE / 10, weight_decay=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

fine_tune_start_epoch = history.epoch[-1] + 1
total_epochs = fine_tune_start_epoch + FINE_TUNE_EPOCHS +1

history_fine = model.fit(
    train_ds,
    epochs=total_epochs,
    initial_epoch=fine_tune_start_epoch,
    validation_data=test_ds,
    callbacks=[early_stopping, reduce_lr]
)

loss, accuracy = model.evaluate(test_ds)
print(f"\nAcurácia Final: {accuracy * 100:.2f}%")
# Out:
# --- Iniciando Fine-Tuning ---
# Epoch 11/21
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 117s 116ms/step - accuracy: 0.8750 - loss: 0.3701 - val_accuracy: 0.9210 - val_loss: 0.2375 - learning_rate: 1.0000e-04
# Epoch 12/21
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9165 - loss: 0.2416 - val_accuracy: 0.9299 - val_loss: 0.2122 - learning_rate: 1.0000e-04
# Epoch 13/21
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9343 - loss: 0.1924 - val_accuracy: 0.9338 - val_loss: 0.1996 - learning_rate: 1.0000e-04
# Epoch 14/21
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9426 - loss: 0.1616 - val_accuracy: 0.9376 - val_loss: 0.1907 - learning_rate: 1.0000e-04
# Epoch 15/21
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 82ms/step - accuracy: 0.9503 - loss: 0.1433 - val_accuracy: 0.9411 - val_loss: 0.1829 - learning_rate: 1.0000e-04
# Epoch 16/21
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9582 - loss: 0.1193 - val_accuracy: 0.9423 - val_loss: 0.1812 - learning_rate: 1.0000e-04
# Epoch 17/21
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 85ms/step - accuracy: 0.9643 - loss: 0.1016 - val_accuracy: 0.9426 - val_loss: 0.1788 - learning_rate: 1.0000e-04
# Epoch 18/21
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step - accuracy: 0.9689 - loss: 0.0908 - val_accuracy: 0.9440 - val_loss: 0.1778 - learning_rate: 1.0000e-04
# Epoch 19/21
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9752 - loss: 0.0756 - val_accuracy: 0.9434 - val_loss: 0.1800 - learning_rate: 1.0000e-04
# Epoch 20/21
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9766 - loss: 0.0697 - val_accuracy: 0.9451 - val_loss: 0.1793 - learning_rate: 1.0000e-04
# Epoch 21/21
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9793 - loss: 0.0627 - val_accuracy: 0.9455 - val_loss: 0.1766 - learning_rate: 1.0000e-04
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.9418 - loss: 0.1910
#
# Acurácia Final: 94.55%

# %%
plot_training_history(history, history_fine)

# %%
# --- 5. Salvar Modelos ---
model.save(H5_MODEL_PATH)
print(f"Modelo Keras salvo em {H5_MODEL_PATH}")

save_tflite_model(model, TFLITE_MODEL_PATH)
# Out:
# Modelo Keras salvo em cifar10_EfficientNetB0_small_finetuned.keras
# Saved artifact at '/tmp/tmp33kcwczl'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_239')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   132912810822352: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   132912810824656: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   132912835416848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835417808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835417424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835418576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835416272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835418384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835420496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835420688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835419536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835418960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835420112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835422224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835418192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835422416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835421456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835420304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835421264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835422800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835423760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835422032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835423568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835424336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835421648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835422992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835424720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835424144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835425488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835423184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835424912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835425872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835426448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835425104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835426640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835423952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835425296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835427600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835427216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835428176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835427408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835426832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835427024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835427792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835426064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835427984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814015312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814014928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835425680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814016272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814014736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814016656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814015504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814016080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814016464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814015120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814017232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814015888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814018000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814018192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814017616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814016848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814018576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814019152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814017808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814017424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814018960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814019536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814020112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814019344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814020496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814018384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814019920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814020304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814018768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814021072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814019728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814021840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814017040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814021264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814021648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814022224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814022800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814022032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814021456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814022608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814023184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814023760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814022992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814024144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814020880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814023568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814023952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814022416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814024720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814023376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814025488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814025680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814025104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814024336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814026064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814026640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814025296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814024912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814026448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814027024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814027600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814026832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814027984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814025872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814027408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814027792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814026256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814028560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814027216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814029328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814024528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814028752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814029136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814029712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814030288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814029520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814028944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814029904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814028368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814028176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814030672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814030480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814030096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814020688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812982544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812982352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812983120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812983888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812984464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812984656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812983312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812984080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812985040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812985616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812984272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812982928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812985424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812986000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812986576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812985808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812986960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812984848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812986384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812986768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812985232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812987536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812986192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812988304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812988496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812987920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812987152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812988880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812989456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812988112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812987728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812989264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812989840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812990416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812989648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812990800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812988688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812990224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812990608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812989072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812991376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812990032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812992144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812987344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812991568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812991952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812992528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812993104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812992336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812991760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812992912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812993488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812994064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812993296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812994448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812991184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812993872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812994256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812992720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812995024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812993680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812995792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812995984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812995408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812994640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812996368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812996944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812995600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812995216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812996752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812997328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812997904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812997136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812994832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812990992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812997712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812996560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812998480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812997520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812996176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812998096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811868432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811868240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811869008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811869776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811870352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811868624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811868816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811870160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811870736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811871312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811870544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811871696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811869584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811871120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811871504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811869968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811872272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811870928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811873040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811869392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811872464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811872848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811873424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811874000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811873232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811872656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811873808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811874384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811874960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811874192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811875344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811872080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811874768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811875152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811873616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811875920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811874576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811876688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811876880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811876304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811875536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811877264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811877840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811876496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811876112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811877648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811878224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811878800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811878032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811879184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811877072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811878608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811878992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811877456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811879760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811878416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811880528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811880720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811880144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811879376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811881104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811881680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811880336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811879952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811881488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811882064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811882640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811881872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811883024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811880912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811882448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811882832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811881296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811883600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811882256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811884368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811884176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811883216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811879568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811883408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811871888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810819856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810819664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810820432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810821200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810821776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810820048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810822160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810820816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810821584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810821968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810820624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810822736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810821392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810823504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810821008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810822928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810823312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810823888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810824464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810822544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810824848: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Modelo salvo em cifar10_EfficientNetB0_small_finetuned.tflite

# %%
# --- 6. Quantização INT8 ---
def representative_dataset_gen():
    """
    Gera um dataset representativo usando uma amostra aleatória do
    conjunto de treinamento para uma calibração mais robusta.
    """
    (x_train, _), _ = cifar10.load_data()

    num_calibration_samples = 20 # Hiperparâmetro: um valor robusto

    # Gera índices aleatórios para garantir uma amostra diversificada
    indices = np.random.choice(x_train.shape[0], num_calibration_samples, replace=False)

    for i in indices:
        image = x_train[i].astype(np.float32)
        image_resized = tf.image.resize(image, (INPUT_SHAPE[0], INPUT_SHAPE[1]))
        image_preprocessed = preprocess_input(image_resized)
        yield [np.expand_dims(image_preprocessed, axis=0)]

save_tflite_model(
    model,
    TFLITE_INT8_MODEL_PATH,
    is_quantized=True,
    representative_ds=representative_dataset_gen,

)

print("\n--- Comparação de Tamanhos ---")
print(f"  Keras (.keras): {os.path.getsize(H5_MODEL_PATH) / (1024*1024):.2f} MB")
print(f"  TFLite (FP32):  {os.path.getsize(TFLITE_MODEL_PATH) / (1024*1024):.2f} MB")
print(f"  TFLite (INT8):  {os.path.getsize(TFLITE_INT8_MODEL_PATH) / (1024*1024):.2f} MB")
# Out:
# Saved artifact at '/tmp/tmpvx4i68_3'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_239')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   132912810822352: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   132912810824656: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   132912835416848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835417808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835417424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835418576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835416272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835418384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835420496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835420688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835419536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835418960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835420112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835422224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835418192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835422416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835421456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835420304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835421264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835422800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835423760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835422032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835423568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835424336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835421648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835422992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835424720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835424144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835425488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835423184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835424912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835425872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835426448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835425104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835426640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835423952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835425296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835427600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835427216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835428176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835427408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835426832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835427024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835427792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835426064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835427984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814015312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814014928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912835425680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814016272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814014736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814016656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814015504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814016080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814016464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814015120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814017232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814015888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814018000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814018192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814017616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814016848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814018576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814019152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814017808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814017424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814018960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814019536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814020112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814019344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814020496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814018384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814019920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814020304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814018768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814021072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814019728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814021840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814017040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814021264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814021648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814022224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814022800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814022032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814021456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814022608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814023184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814023760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814022992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814024144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814020880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814023568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814023952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814022416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814024720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814023376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814025488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814025680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814025104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814024336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814026064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814026640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814025296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814024912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814026448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814027024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814027600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814026832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814027984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814025872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814027408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814027792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814026256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814028560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814027216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814029328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814024528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814028752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814029136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814029712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814030288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814029520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814028944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814029904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814028368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814028176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814030672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814030480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814030096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912814020688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812982544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812982352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812983120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812983888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812984464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812984656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812983312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812984080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812985040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812985616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812984272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812982928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812985424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812986000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812986576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812985808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812986960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812984848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812986384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812986768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812985232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812987536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812986192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812988304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812988496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812987920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812987152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812988880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812989456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812988112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812987728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812989264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812989840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812990416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812989648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812990800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812988688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812990224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812990608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812989072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812991376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812990032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812992144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812987344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812991568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812991952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812992528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812993104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812992336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812991760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812992912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812993488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812994064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812993296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812994448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812991184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812993872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812994256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812992720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812995024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812993680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812995792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812995984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812995408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812994640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812996368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812996944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812995600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812995216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812996752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812997328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812997904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812997136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812994832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812990992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812997712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812996560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812998480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812997520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812996176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912812998096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811868432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811868240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811869008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811869776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811870352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811868624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811868816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811870160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811870736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811871312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811870544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811871696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811869584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811871120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811871504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811869968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811872272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811870928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811873040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811869392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811872464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811872848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811873424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811874000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811873232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811872656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811873808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811874384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811874960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811874192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811875344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811872080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811874768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811875152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811873616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811875920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811874576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811876688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811876880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811876304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811875536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811877264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811877840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811876496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811876112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811877648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811878224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811878800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811878032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811879184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811877072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811878608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811878992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811877456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811879760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811878416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811880528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811880720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811880144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811879376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811881104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811881680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811880336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811879952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811881488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811882064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811882640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811881872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811883024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811880912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811882448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811882832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811881296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811883600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811882256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811884368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811884176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811883216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811879568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811883408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912811871888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810819856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810819664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810820432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810821200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810821776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810820048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810822160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810820816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810821584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810821968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810820624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810822736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810821392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810823504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810821008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810822928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810823312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810823888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810824464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810822544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132912810824848: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Modelo salvo em cifar10_EfficientNetB0_small_finetuned_int8.tflite
#
# --- Comparação de Tamanhos ---
#   Keras (.keras): 25.03 MB
#   TFLite (FP32):  15.34 MB
#   TFLite (INT8):  4.69 MB

# %%
import tensorflow as tf
import numpy as np


def evaluate_tflite_int8_model(model_path, num_images_to_test=None):
    print(f"\nAvaliando modelo INT8: {model_path}")

    (_, _), (x_test, y_test) = cifar10.load_data()

    interpreter = tf.lite.Interpreter(
    model_path=model_path,
    experimental_op_resolver_type=tf.lite.experimental.OpResolverType.BUILTIN_WITHOUT_DEFAULT_DELEGATES
)


    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()[0]
    output_details = interpreter.get_output_details()[0]

    input_scale, input_zero_point = input_details["quantization"]
    output_scale, output_zero_point = output_details["quantization"]

    input_shape = input_details['shape']
    height, width = input_shape[1], input_shape[2]

    correct_predictions = 0
    total_images = len(x_test) if num_images_to_test is None else num_images_to_test

    for i in range(total_images):
        image_float32 = x_test[i].astype(np.float32)
        image_resized = tf.image.resize(image_float32, [height, width])
        image_preprocessed = preprocess_input(image_resized)

        image_quantized = (image_preprocessed / input_scale) + input_zero_point
        image_quantized = np.expand_dims(image_quantized.numpy().astype(input_details["dtype"]), axis=0)

        interpreter.set_tensor(input_details['index'], image_quantized)
        interpreter.invoke()

        output_data = interpreter.get_tensor(output_details['index'])
        output_dequantized = (output_data.astype(np.float32) - output_zero_point) * output_scale

        predicted_label = np.argmax(output_dequantized)
        true_label = y_test[i][0]

        if predicted_label == true_label:
            correct_predictions += 1

    accuracy = (correct_predictions / total_images) * 100
    print(f"Acurácia do modelo TFLite INT8: {accuracy:.2f}% ({correct_predictions}/{total_images})")
    return accuracy

# %%
evaluate_tflite_int8_model(TFLITE_INT8_MODEL_PATH)
# Out:
# Avaliando modelo INT8: cifar10_EfficientNetB0_small_finetuned_int8.tflite
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# Acurácia do modelo TFLite INT8: 81.15% (8115/10000)
# 81.15
